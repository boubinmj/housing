# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from subprocess import check_output
print(check_output(["ls", "data"]).decode("utf8"))
# Out:
# data_description.txt
# sample_submission.csv
# test.csv
# train.csv

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# import data
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

for i in range(train.shape[1]):
    if(train.iloc[:,i].isnull().sum()>0):
        print(list(train.columns.values)[i] + ": " + str(train.iloc[:,i].isnull().sum()))
# Out:
# LotFrontage: 259
# Alley: 1369
# MasVnrType: 8
# MasVnrArea: 8
# BsmtQual: 37
# BsmtCond: 37
# BsmtExposure: 38
# BsmtFinType1: 37
# BsmtFinType2: 38
# Electrical: 1
# FireplaceQu: 690
# GarageType: 81
# GarageYrBlt: 81
# GarageFinish: 81
# GarageQual: 81
# GarageCond: 81
# PoolQC: 1453
# Fence: 1179
# MiscFeature: 1406

# %%
#list(train.columns.values)
train['PoolQC']

train.drop(['Alley', 'MiscFeature', 'PoolQC'], axis = 1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  \
# 0        1          60       RL         65.0     8450   Pave      Reg
# 1        2          20       RL         80.0     9600   Pave      Reg
# 2        3          60       RL         68.0    11250   Pave      IR1
# 3        4          70       RL         60.0     9550   Pave      IR1
# 4        5          60       RL         84.0    14260   Pave      IR1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave      Reg
# 1456  1457          20       RL         85.0    13175   Pave      Reg
# 1457  1458          70       RL         66.0     9042   Pave      Reg
# 1458  1459          20       RL         68.0     9717   Pave      Reg
# 1459  1460          20       RL         75.0     9937   Pave      Reg
#
#      LandContour Utilities LotConfig  ... 3SsnPorch ScreenPorch PoolArea  \
# 0            Lvl    AllPub    Inside  ...         0           0        0
# 1            Lvl    AllPub       FR2  ...         0           0        0
# 2            Lvl    AllPub    Inside  ...         0           0        0
# 3            Lvl    AllPub    Corner  ...         0           0        0
# 4            Lvl    AllPub       FR2  ...         0           0        0
# ...          ...       ...       ...  ...       ...         ...      ...
# 1455         Lvl    AllPub    Inside  ...         0           0        0
# 1456         Lvl    AllPub    Inside  ...         0           0        0
# 1457         Lvl    AllPub    Inside  ...         0           0        0
# 1458         Lvl    AllPub    Inside  ...         0           0        0
# 1459         Lvl    AllPub    Inside  ...         0           0        0
#
#       Fence MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       NaN       0      2    2008        WD         Normal     208500
# 1       NaN       0      5    2007        WD         Normal     181500
# 2       NaN       0      9    2008        WD         Normal     223500
# 3       NaN       0      2    2006        WD        Abnorml     140000
# 4       NaN       0     12    2008        WD         Normal     250000
# ...     ...     ...    ...     ...       ...            ...        ...
# 1455    NaN       0      8    2007        WD         Normal     175000
# 1456  MnPrv       0      2    2010        WD         Normal     210000
# 1457  GdPrv    2500      5    2010        WD         Normal     266500
# 1458    NaN       0      4    2010        WD         Normal     142125
# 1459    NaN       0      6    2008        WD         Normal     147500
#
# [1460 rows x 78 columns]

# %%
### Categorical Variables
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import LabelEncoder

for i in range(train.shape[1]):
    if train.iloc[:,i].dtypes == object:
        lbl = LabelEncoder()
        lbl.fit(list(train.iloc[:,i].values) + list(test.iloc[:,i].values))
        train.iloc[:,i] = lbl.transform(list(train.iloc[:,i].values))
        test.iloc[:,i] = lbl.transform(list(test.iloc[:,i].values))

print(train['SaleCondition'].unique())
print(train['Street'].unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-79da8cdfb802> in <module>
#       3 from sklearn.preprocessing import LabelEncoder
#       4
# ----> 5 for i in range(train.shape[1]):
#       6     if train.iloc[:,i].dtypes == object:
#       7         lbl = LabelEncoder()
#
# NameError: name 'train' is not defined

# %%
import missingno as msno
# keep ID for submission
train_ID = train['Id']
test_ID = test['Id']

# split data for training
y_train = train['SalePrice']
X_train = train.drop(['Id','SalePrice'], axis=1)
X_test = test.drop('Id', axis=1)

# dealing with missing data
Xmat = pd.concat([X_train, X_test])
Xmat = Xmat.drop(['LotFrontage','MasVnrArea','GarageYrBlt'], axis=1)
Xmat = Xmat.fillna(Xmat.median())

# check whether there are still nan
import missingno as msno
msno.matrix(df=Xmat, figsize=(20,14), color=(0.5,0,0))

# %%
# train and test
X_train = Xmat.iloc[:train.shape[0],:]
X_test = Xmat.iloc[train.shape[0]:,:]

# Compute the correlation matrix
corr = X_train.corr()

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix

np.random.seed(123)

train_p = X_train.iloc[:,1:-1]

label_encoder = LabelEncoder()
train_p.iloc[:,0] = label_encoder.fit_transform(train_p.iloc[:,0]).astype('float64')

corr = train_p.corr()

sns.heatmap(corr)

# %%
columns = np.full((corr.shape[0],), True, dtype=bool)
print(columns)
print(corr.shape)
print(train_p.shape)
for i in range(corr.shape[0]):
    for j in range(i+1, corr.shape[0]):
        if corr.iloc[i,j] >= 0.2:
            if columns[j]:
                columns[j] = False
                
selected_columns = train_p.columns[columns]
train_new = train_p[selected_columns]
train_new.columns
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True]
# (74, 74)
# (1460, 74)
#       MSZoning  LotArea  Street  Alley  LotShape  LandContour  Utilities  \
# 0          3.0     8450       1      2         3            3          0
# 1          3.0     9600       1      2         3            3          0
# 2          3.0    11250       1      2         0            3          0
# 3          3.0     9550       1      2         0            3          0
# 4          3.0    14260       1      2         0            3          0
# ...        ...      ...     ...    ...       ...          ...        ...
# 1455       3.0     7917       1      2         3            3          0
# 1456       3.0    13175       1      2         3            3          0
# 1457       3.0     9042       1      2         3            3          0
# 1458       3.0     9717       1      2         3            3          0
# 1459       3.0     9937       1      2         3            3          0
#
#       Neighborhood  Condition1  Condition2  ...  EnclosedPorch  3SsnPorch  \
# 0                5           2           2  ...              0          0
# 1               24           1           2  ...              0          0
# 2                5           2           2  ...              0          0
# 3                6           2           2  ...            272          0
# 4               15           2           2  ...              0          0
# ...            ...         ...         ...  ...            ...        ...
# 1455             8           2           2  ...              0          0
# 1456            14           2           2  ...              0          0
# 1457             6           2           2  ...              0          0
# 1458            12           2           2  ...            112          0
# 1459             7           2           2  ...              0          0
#
#       ScreenPorch  PoolArea  PoolQC  MiscFeature  MiscVal  MoSold  YrSold  \
# 0               0         0       3            4        0       2    2008
# 1               0         0       3            4        0       5    2007
# 2               0         0       3            4        0       9    2008
# 3               0         0       3            4        0       2    2006
# 4               0         0       3            4        0      12    2008
# ...           ...       ...     ...          ...      ...     ...     ...
# 1455            0         0       3            4        0       8    2007
# 1456            0         0       3            4        0       2    2010
# 1457            0         0       3            2     2500       5    2010
# 1458            0         0       3            4        0       4    2010
# 1459            0         0       3            4        0       6    2008
#
#       SaleType
# 0            8
# 1            8
# 2            8
# 3            8
# 4            8
# ...        ...
# 1455         8
# 1456         8
# 1457         8
# 1458         8
# 1459         8
#
# [1460 rows x 35 columns]

# %%
for i in range(train_new.shape[1]):
    if(train_new.iloc[:,i].isnull().sum()>0):
        print(list(train_new.columns.values)[i] + ": " + str(train_new.iloc[:,i].isnull().sum()))
